# %%
import ray
from ray import serve

# %%
ray.init()
# Out:
# 2023-10-23 08:47:42,431	INFO worker.py:1458 -- Connecting to existing Ray cluster at address: 10.244.20.58:6379...
# 2023-10-23 08:47:42,439	INFO worker.py:1633 -- Connected to Ray cluster. View the dashboard at 10.244.20.58:8265
# RayContext(dashboard_url='10.244.20.58:8265', python_version='3.10.12', ray_version='2.7.0', ray_commit='b4bba4717f5ba04ee25580fe8f88eed63ef0c5dc', protocol_version=None)

# %%
try:
    serve.delete('vicuna13bapi')
except Exception as e:
    pass
# Out:
# (ServeController pid=30057) INFO 2023-10-21 10:08:19,838 controller 30057 deployment_state.py:1707 - Removing 2 replicas from deployment 'SnowflakeVLLMLLAMA2Deployment' in application 'llama2api'.
# (ServeController pid=30057) INFO 2023-10-21 10:08:19,841 controller 30057 http_state.py:260 - Start to drain the proxy actor on node 837e8dd50585339a667af6865eb9ca3c55c1f5b3b6f8dbb48ed6e315
# (ServeController pid=30057) INFO 2023-10-21 10:08:19,842 controller 30057 http_state.py:260 - Start to drain the proxy actor on node 9fbe0c8c4fc03e8809213c344b8aacedc98990552551f3f50be49ddf
# (ServeController pid=30057) INFO 2023-10-21 10:08:21,900 controller 30057 deployment_state.py:2027 - Replica llama2api#SnowflakeVLLMLLAMA2Deployment#LAWFEO is stopped.
# (ServeController pid=30057) INFO 2023-10-21 10:08:22,004 controller 30057 deployment_state.py:2027 - Replica llama2api#SnowflakeVLLMLLAMA2Deployment#OUxlvW is stopped.
# ...
